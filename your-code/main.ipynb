# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import pandas as pd
import numpy as np
import requests
import json

#git token copy pasted
git_token = 'pasted somewhere'

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here

url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'
repo_info = requests.get(url, auth = ('miguestepa', git_token))


repo_info_json = repo_info.json()

for elem in repo_info_json:
    print(elem.items)


print(json.dumps(repo_info_json[1], indent = 4, sort_keys = True))
# Out:
# <built-in method items of dict object at 0x000001A4DC5144C0>
# <built-in method items of dict object at 0x000001A4DC5573C0>
# <built-in method items of dict object at 0x000001A4DC6E6340>
# <built-in method items of dict object at 0x000001A4DC557040>
# <built-in method items of dict object at 0x000001A4DC639980>
# <built-in method items of dict object at 0x000001A4DC53E880>
# <built-in method items of dict object at 0x000001A4DC55B440>
# <built-in method items of dict object at 0x000001A4DC6D7200>
# <built-in method items of dict object at 0x000001A4DC6D7240>
# <built-in method items of dict object at 0x000001A4DC708480>
# <built-in method items of dict object at 0x000001A4DC708D40>
# <built-in method items of dict object at 0x000001A4DC708B40>
# <built-in method items of dict object at 0x000001A4DC708800>
# <built-in method items of dict object at 0x000001A4DC708500>
# <built-in method items of dict object at 0x000001A4DC70BB40>
# {
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here

# Instead of creating a normal list, we will create a numpy list so we can use the .unique() method.

languages = np.array([])

#Since it has a dictionary structure, we have to make a double relation when trying to access the items.
for elem in forks_json:
    for key, value in elem.items():
        if key == 'language' and value != None:
            languages = np.append(languages, np.array([value]))

# Now we print the non-repeated values using unique()
list(np.unique(languages))
# Out:
# ['HTML', 'Jupyter Notebook']

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
# The url for this exercise is:
url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits'

# We take our variable from challenge 1
commits_info = requests.get(url, auth = ('miguestepa', git_token))
commits = commits_info.json()

# Since it has a dictionary structure, we have to make a double relation when trying to access the items.
n_commits = []
for elem in commits:
    for key, value in elem.items():
        if key == 'author':
            n_commits.append(key)
            

len(n_commits)
# Out:
# 30

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
#Done in the previous exercise.

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here

url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'
repo = requests.get(url, auth = ('miguestepa', git_token))
joke_jason = repo.json()
print(json.dumps(joke_jason, indent = 2, sort_keys = True))
# Out:
# [
#   {
#     "_links": {
#       "git": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf",
#       "html": "https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore",
#       "self": "https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master"
#     },
#     "download_url": "https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore",
#     "git_url": "https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf",
#     "html_url": "https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore",
#     "name": ".gitignore",
#     "path": ".gitignore",
#     "sha": "e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf",
#     "size": 10,
#     "type": "file",
#     "url": "https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master"
#   },
#   {
#     "_links": {
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
